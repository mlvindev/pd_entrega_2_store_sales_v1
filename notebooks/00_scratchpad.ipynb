# %% [markdown]
# #### Solo para obtener el formato del json

# %%
import numpy as np
import pandas as pd

# %%
# Cargar el dataset
dataset = pd.read_csv('../data/raw/stores_sales_forecasting_updated_v3.1.csv', 
                 sep=';',
                 encoding='utf-8')

# Inspección visual
dataset.head(5)
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0     849  CA-2017-107503   1/01/2017   6/01/2017  Standard Class    GA-14725
# 1    4010  CA-2017-144463   1/01/2017   5/01/2017  Standard Class    SC-20725
# 2    8071  CA-2017-151750   1/01/2017   5/01/2017  Standard Class    JM-15250
# 3    8072  CA-2017-151750   1/01/2017   5/01/2017  Standard Class    JM-15250
# 4     867  CA-2014-149020  10/01/2014  15/01/2014  Standard Class    AJ-10780
#
#        Customer Name    Segment        Country         City  ... Postal Code  \
# 0      Guy Armstrong   Consumer  United States       Lorain  ...       44052
# 1  Steven Cartwright   Consumer  United States  Los Angeles  ...       90036
# 2       Janet Martin   Consumer  United States   Huntsville  ...       77340
# 3       Janet Martin   Consumer  United States   Huntsville  ...       77340
# 4     Anthony Jacobs  Corporate  United States  Springfield  ...       22153
#
# ...

# %%
dataset.iloc[0:10, :].to_json("../data/raw/stores_sales_forecasting_updated_v3.1.json", orient="records")
